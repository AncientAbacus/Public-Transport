# %%
import pandas as pd

# Specify the path to your CSV file
csv_file_path = '/Users/ginoangelici/Projects/DS3/Public-Transport/data/ITF_INDICATORS_18012024232053067.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df
# Out:
#       COUNTRY     Country     INDICATOR  \
# 0         ALB     Albania   IND-ENE-GDP
# 1         ALB     Albania   IND-ENE-GDP
# 2         ALB     Albania   IND-ENE-GDP
# 3         ALB     Albania   IND-ENE-GDP
# 4         ALB     Albania   IND-ENE-GDP
# ...       ...         ...           ...
# 13938     CRI  Costa Rica  IND-ENE-NAVI
# 13939     CRI  Costa Rica  IND-ENE-NAVI
# 13940     CRI  Costa Rica  IND-ENE-NAVI
# 13941     CRI  Costa Rica  IND-ENE-NAVI
# 13942     CRI  Costa Rica  IND-ENE-NAVI
#
#                                                Indicator  YEAR  Year  \
# 0      CO2 emissions from transport in tonnes per one...  2000  2000
# 1      CO2 emissions from transport in tonnes per one...  2001  2001
# 2      CO2 emissions from transport in tonnes per one...  2002  2002
# 3      CO2 emissions from transport in tonnes per one...  2003  2003
# 4      CO2 emissions from transport in tonnes per one...  2004  2004
# ...

# %%
df_US = df[(df["COUNTRY"]=="USA") & (df["Indicator"]=="CO2 emissions from transport in tonnes per inhabitant")]

df_UK = df[(df["Country"]=="United Kingdom") & (df["Indicator"]=="CO2 emissions from transport in tonnes per inhabitant")]
df_UK
# Out:
#       COUNTRY         Country   INDICATOR  \
# 10205     GBR  United Kingdom  IND-ENE-PC
# 10206     GBR  United Kingdom  IND-ENE-PC
# 10207     GBR  United Kingdom  IND-ENE-PC
# 10208     GBR  United Kingdom  IND-ENE-PC
# 10209     GBR  United Kingdom  IND-ENE-PC
# 10210     GBR  United Kingdom  IND-ENE-PC
# 10211     GBR  United Kingdom  IND-ENE-PC
# 10212     GBR  United Kingdom  IND-ENE-PC
# 10213     GBR  United Kingdom  IND-ENE-PC
# 10214     GBR  United Kingdom  IND-ENE-PC
# 10215     GBR  United Kingdom  IND-ENE-PC
# 10216     GBR  United Kingdom  IND-ENE-PC
# 10217     GBR  United Kingdom  IND-ENE-PC
# 10218     GBR  United Kingdom  IND-ENE-PC
# 10219     GBR  United Kingdom  IND-ENE-PC
# 10220     GBR  United Kingdom  IND-ENE-PC
# 10221     GBR  United Kingdom  IND-ENE-PC
# 10222     GBR  United Kingdom  IND-ENE-PC
# 10223     GBR  United Kingdom  IND-ENE-PC
# 10224     GBR  United Kingdom  IND-ENE-PC
# 10225     GBR  United Kingdom  IND-ENE-PC
# ...

# %%
from IPython.display import display

# Assuming 'result' is your DataFrame

# Specify the path to your CSV file
csv_file_path = 'data/ITF_CQ_25012024235411391.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

display(df.groupby(['Variable','COUNTRY']).agg('mean'))
# Out:
# /var/folders/39/pbkz55tn77x5j29wl0sjvkn40000gn/T/ipykernel_80978/3613571599.py:11: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   display(df.groupby(['Variable','COUNTRY']).agg('mean'))
#                          YEAR         Year  PowerCode Code  \
# Variable COUNTRY
# Cycles   ARM      2014.500000  2014.500000             0.0
#          AUT      2014.000000  2014.000000             0.0
#          BEL      2014.000000  2014.000000             0.0
#          BGR      2014.000000  2014.000000             0.0
#          BLR      2014.000000  2014.000000             0.0
# ...                       ...          ...             ...
# Unknown  SRB      2013.363636  2013.363636             0.0
#          SVN      2014.000000  2014.000000             0.0
# ...

# %%
import pandas as pd

rrdf = pd.read_csv('/Users/ginoangelici/Projects/DS3/Public-Transport/data/OECD_Rail_and_Road.csv')
rrdf
# Out:
#      LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 0         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1970   12473.066624
# 1         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1971   12674.783011
# 2         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1972   11616.093761
# 3         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1973   11474.354465
# 4         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1974   10520.293577
# ...       ...         ...     ...      ...       ...   ...            ...
# 5637      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2016  114910.267100
# 5638      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2017  117659.567000
# 5639      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2018  121599.489300
# 5640      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2019  124141.200000
# 5641      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2020  113200.000000
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# ...

# %%
rail_rrdf = rrdf[(rrdf["TIME"]==2010) & (rrdf["SUBJECT"]=="RAIL")]
rail_rrdf
rail_rrdf
# Out:
#      LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 40        AUS  PASSTRANSP    RAIL  MLN_PKM         A  2010   14534.639315
# 146       AUT  PASSTRANSP    RAIL  MLN_PKM         A  2010   10737.000000
# 222       BEL  PASSTRANSP    RAIL  MLN_PKM         A  2010   10403.000000
# 297       CAN  PASSTRANSP    RAIL  MLN_PKM         A  2010    1404.000000
# 340       CZE  PASSTRANSP    RAIL  MLN_PKM         A  2010    6591.000000
# 423       DNK  PASSTRANSP    RAIL  MLN_PKM         A  2010    6577.000000
# 509       FIN  PASSTRANSP    RAIL  MLN_PKM         A  2010    3959.000000
# 614       FRA  PASSTRANSP    RAIL  MLN_PKM         A  2010  102167.000000
# 720       DEU  PASSTRANSP    RAIL  MLN_PKM         A  2010   83886.000000
# 824       GRC  PASSTRANSP    RAIL  MLN_PKM         A  2010    1337.000000
# 908       HUN  PASSTRANSP    RAIL  MLN_PKM         A  2010    7692.000000
# 1014      ISL  PASSTRANSP    RAIL  MLN_PKM         A  2010            NaN
# ...

# %%
x = rail_rrdf['LOCATION']
rrdf
# Out:
#      LOCATION   INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 0         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1970   12473.066624
# 1         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1971   12674.783011
# 2         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1972   11616.093761
# 3         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1973   11474.354465
# 4         AUS  PASSTRANSP    RAIL  MLN_PKM         A  1974   10520.293577
# ...       ...         ...     ...      ...       ...   ...            ...
# 5637      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2016  114910.267100
# 5638      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2017  117659.567000
# 5639      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2018  121599.489300
# 5640      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2019  124141.200000
# 5641      UZB  PASSTRANSP    ROAD  MLN_PKM         A  2020  113200.000000
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# ...

# %%
pd.read_csv("/Users/ginoangelici/Projects/DS3/Public-Transport/data/API_IS.RRS.PASG.KM_DS2_en_csv_v2_6304065.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.read_csv("/Users/ginoangelici/Projects/DS3/Public-Transport/data/API_IS.RRS.PASG.KM_DS2_en_csv_v2_6304065.csv")
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...
